# %% [markdown]
# # 1268. Search Suggestions System
#
# <br/>
#
# 📎 문제 출처: https://leetcode.com/problems/search-suggestions-system/
#
#
# > You are given an array of strings `products` and a string `searchWord`. <br/><br/>
# Design a system that suggests at most three product names from `products` after each character of `searchWord` is typed. Suggested products should have common prefix with `searchWord`. If there are more than three products with a common prefix return the three lexicographically minimums products. <br/><br/>
# Return a list of lists of the suggested products after each character of `searchWord` is typed.

# %%
class Solution(object):
    def suggestedProducts(self, products, searchWord):
        """
        :type products: List[str]
        :type searchWord: str
        :rtype: List[List[str]]
        """

# %% [markdown]
# ### 문제 해석
# - 입력값: 문자열 products, searchWord
# > `searchWord`의 각 단어를 작성한 뒤, `products`에서 최대 3개의 이름을 제안해라. <br/>
# 제안된 products는 `searchWord`라는 공통 접두사를 가져야 하고, 이 공통 접두사가 3개 이상이라면 3개의 lexicographically minimum product를 반환해라
# - 반환값: `searchWord`의 각각의 단어가 작성된 이후 제안된 products의 리스트 반환하기
#
# > ❓ `lexicographically minimum product`
# > - `lexicographically`: 사전 순서대로
# > - 사전 순서대로 앞에서부터 3개의 product 반환하기

# %%
class Solution(object):
    def suggestedProducts(self, products, searchWord):
        
        products = sorted(products) # 사전 순 정렬
        
        result = [[] for i in range(len(searchWord))] # 길이가 정해진 리스트 만들기 (searchWord 길이만큼 리스트 생김)
        
        for i in range(len(searchWord)):
            for product in products:
                if (searchWord[0:i+1] == product[0:i+1]) and (len(result[i]) < 3):
                    result[i].append(product)

        return result

# %%
sol = Solution()
sol.suggestedProducts(products=['mobile', 'mouse', 'moneypot', 'monitor', 'mousepad'], searchWord='mouse')
# Out:
# [['mobile', 'moneypot', 'monitor'],
#  ['mobile', 'moneypot', 'monitor'],
#  ['mouse', 'mousepad'],
#  ['mouse', 'mousepad'],
#  ['mouse', 'mousepad']]

# %% [markdown]
# > ex) `m`, `mo`, `mou`, `mous`, `mouse`를 차례차례 proudcts에 있는 각각의 단어들과 비교해가며 공통 접두사를 가지면 최대 3개의 단어를 return해준다.

# %%
searchWord = 'mouse'

result = [[] for i in range(len(searchWord))]
print(result)
# Out:
# [[], [], [], [], []]

# %%
sol.suggestedProducts(products=['havana'], searchWord='havana')
# Out:
# [['havana'], ['havana'], ['havana'], ['havana'], ['havana'], ['havana']]

# %%
sol.suggestedProducts(products = ["bags","baggage","banner","box","cloths"], searchWord = "bags")
# Out:
# [['baggage', 'bags', 'banner'],
#  ['baggage', 'bags', 'banner'],
#  ['baggage', 'bags'],
#  ['bags']]

# %% [markdown]
# ![image.png](attachment:image.png)

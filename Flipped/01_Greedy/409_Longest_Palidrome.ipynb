# %% [markdown]
# # 409. Longest Palindrome
#
# <br/>
#
# 📎 문제 출처: https://leetcode.com/problems/longest-palindrome/
#
# > Given a string s which consists of lowercase or uppercase letters, return the length of the longest palindrome that can be built with those letters. <br/> <br/>
# Letters are case sensitive, for example, "Aa" is not considered a palindrome here.
#
#
# - 주어진 string으로 만들 수 있는 가장 긴 회문의 개수 출력하기

# %%
class Solution(object):
    def longestPalindrome(self, s):
        """
        :type s: str
        :rtype: int
        """

# %% [markdown]
# ### 문제 접근법
# - 회문은 문장의 앞과 뒤가 대칭적이어야 한다.
# - 알파벳의 개수가 짝수 개라면 모든 알파벳이 회문에 들어갈 수 있을 것.
# - 알파벳의 개수가 홀수 개라면 정 가운데 or 대칭적으로 양 끝에 들어갈 수 있을 것.
#     - but, 만약 홀수 개인 알파벳이 여러 개라면 ?
#     - 한 개의 알파벳은 홀수 개가 들어갈 수 있지만, 다른 홀수 개를 가진 알파벳은 그 중 최대의 짝수 개만 들어갈 수 있을 것
#     - 홀수 개인 알파벳 중 그 길이가 가장 긴 알파벳은 전부가, 나머지 알파벳들은 그 중에서 -1을 뺀 짝수 개만 들어갈 경우에 가장 길 것이다.

# %% [markdown]
# ### 1st-try
# - 처음엔 홀수 개인 알파벳의 경우에 길이가 가장 긴 홀수 값만 들어갈 수 있다고 생각했다.
# - 즉, aaaaabbb일 경우 회문에 aaaaa만 들어갈 수 있다고 생각! (bbb중 bb도 들어갈 수 있음)

# %%
from collections import Counter

# %%
class Solution(object):
    def longestPalindrome(self, s):
        """
        :type s: str
        :rtype: int
        """
        answer = 0
        
        # 각 원소가 짝수 개로 있어야 회문에 쓸 수 있음
        counter = Counter(s)
        odd = []
        
        for c in counter.values():
            if c % 2 == 0:
                answer += c # 짝수 개면 그 길이만큼 회문에 들어갈 수 있음
            else:
                odd.append(c)
        
        if len(odd) > 0: # 홀수 개의 알파벳이 있다면
            answer += max(odd) # 그 최댓값
                
        return answer

# %%
solution = Solution()
solution.longestPalindrome(s = "abccccdd")
# Out:
# 7

# %%
solution.longestPalindrome(s = "a")
# Out:
# 1

# %%
solution.longestPalindrome(s = "bb")
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2nd-try
# - `odd`라는 홀수 알파벳 개수가 모인 리스트에서 애초에 1씩 뺀만큼(한 개 빼고는 짝수 개를 더해야 하므로) 저장하고, 마지막에 1을 더하는 방법
# - 여기선 짝수 알파벳만 1가지 나올 경우를 고려하지 않았다 .. ^^

# %%
class Solution(object):
    def longestPalindrome(self, s):
        """
        :type s: str
        :rtype: int
        """
        answer = 0
        
        # 각 원소가 짝수 개로 있어야 회문에 쓸 수 있음
        counter = collections.Counter(s)
        odd = []
        
        for c in counter.values():
            if c % 2 == 0:
                answer += c # 짝수 개면 그 길이만큼 회문에 들어갈 수 있음
            else:
                odd.append(c-1)
                
        for v in odd:
            answer += v
        
        answer += 1
                
        return answer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 🐥 3rd-try

# %%
class Solution(object):
    def longestPalindrome(self, s):
        """
        :type s: str
        :rtype: int
        """
        answer = 0
        
        # 각 원소가 짝수 개로 있어야 회문에 쓸 수 있음
        counter = collections.Counter(s)
        odd = []
        
        for c in counter.values():
            if c % 2 == 0:
                answer += c # 짝수 개면 그 길이만큼 회문에 들어갈 수 있음
            else:
                odd.append(c-1)
                
        for v in odd:
            answer += v
        
        if len(odd) > 0: # 홀수 개의 알파벳이 있을 경우에만!
            answer += 1
                
        return answer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 53. Maximum Subarray
#
# <br/>
#
# 📎 문제 출처: https://leetcode.com/problems/maximum-subarray/
#
#
# > Given an integer array nums, find the contiguous subarray (containing at least one number) which has the largest sum and return its sum. <br/><br/>
# A subarray is a contiguous part of an array.

# %%
class Solution(object):
    def maxSubArray(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """

# %% [markdown]
# ### 문제 해석
# `nums`라는 integer array가 주어질 때, `largest sum`을 가지는 **contiguous subarray**를 구해 그 `sum`을 return해라!

# %% [markdown]
# ### 문제 접근
# ### ✔️ 1st-try
# - 일단 리스트에서 가장 큰 max 값을 따로 저장한다. ~이 값은 무조건 포함되어야 한다고 판단~
#     - 아 근데 꼭 이런 건 아니구나 ,,,
# - nums 리스트를 차례대로 접근하며 누적해 더해보는데, 합이 음수면 굳이 더할 필요 없는 수라고 판단 -> sum=0으로 변경
# - 최소인 최댓값은 max값 하나 일 때일 것이다. sum이 이 값보다 크면 답이 될 수 있는 후보가 됨! -> maxsum이라는 변수에 저장해두기
# - 계속해서 더해주는데 maxsum보다 커지면 다시 답이 될 수 있는 후보이므로 확인하여 교체해준다.

# %%
s = [-2, 1, -3, 4, -1, 2, 1, -5, 4]
max(s)
# Out:
# 4

# %%
class Solution(object):
    def maxSubArray(self, nums):
        sum = 0
        maxsum = max(nums)
        
        for n in nums:
            sum += n
            
            if sum < 0:
                sum = 0
            
            if sum > maxsum: # 4보다 크면
                maxsum = sum

        
#         for i in range(len(nums)):
#             if nums[i] == max(nums):
#                 index = i
# #                 print(i, max(nums))
#                 break
    
        
        return maxsum

# %%
sol = Solution()
sol.maxSubArray([-2, 1, -3, 4, -1, 2, 1, -5, 4])
# Out:
# 6

# %% [markdown]
# ### - 해석
# -1 -> 0 <br/>
# -3 -> 0 <br/>
# 4 <br/>
# 3 <br/>
# 5 # 저장 <br/>
# 6 # 저장 <br/>
# 1 <br/>
# 5 <br/>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > 틀린 이유: 첫 조건문이 `sum<0`일 경우 `sum=0`으로 두어 입력 값이 음수 뿐일 경우를 고려해주지 않았다.
# > - 두 if문의 위치를 바꿔주자.

# %% [markdown]
# ### ✔️ 2nd-try

# %%
class Solution(object):
    def maxSubArray(self, nums):
        sum = 0
        maxsum = max(nums)
        
        for n in nums:
            sum += n
            
            if sum > maxsum:
                maxsum = sum
            
            if sum < 0:
                sum = 0        
        
        return maxsum

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 추가
# - prefix sum에 대해 공부해보자 !!!
